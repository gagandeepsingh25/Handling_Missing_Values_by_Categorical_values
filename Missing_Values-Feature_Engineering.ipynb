# %% [markdown]
# There are many ways data can end up with missing values. For example
#
# A 2 bedroom house wouldn't include an answer for How large is the third bedroom
# Someone being surveyed may choose not to share their income
# Python libraries represent missing numbers as nan which is short for "not a number".

# %%
import pandas as pd

# %%
df = pd.read_csv('Melbourne_housing_FULL.csv')

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
##find whata null values are present 
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df[df["Price"].isnull()]
# Out:
#                Suburb             Address  Rooms Type  Price Method  \
# 0          Abbotsford       68 Studley St      2    h    NaN     SS
# 3          Abbotsford  18/659 Victoria St      3    u    NaN     VB
# 7          Abbotsford        16 Maugie St      4    h    NaN     SN
# 8          Abbotsford        53 Turner St      2    h    NaN      S
# 9          Abbotsford        99 Turner St      2    h    NaN      S
# ...               ...                 ...    ...  ...    ...    ...
# 34829  West Melbourne    9/11 Anderson St      3    u    NaN      S
# 34834   Wheelers Hill        112 Jells Rd      4    h    NaN     PN
# 34835   Wheelers Hill          20 Mill Ct      3    h    NaN      S
# 34845         Windsor          13 Mary St      4    h    NaN      W
# 34850         Wollert    15 Rockgarden Wy      3    h    NaN     SP
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
import numpy as np
df['Bathroom'] = np.where(df['Landsize'].isnull(),1,0) ## if it has null convert to 1 otherwise keep it as 0.
df['Bathroom'].mean()
# Out:
# 0.3388128639871475

# %%
df['Bathroom']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 34852    0
# 34853    0
# 34854    0
# 34855    1
# 34856    0
# Name: Bathroom, Length: 34857, dtype: int64

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...         0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...         0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...         0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...         0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...         0  0.0     134.0         150.0
#
# ...

# %%
df.groupby(['Address'])['Bathroom'].mean()
# Out:
# Address
# 1 Abercrombie St    0.0
# 1 Aberfeldie Wy     1.0
# 1 Acacia St         0.0
# 1 Acheron Av        1.0
# 1 Adelle Ct         0.0
#                    ...
# 9a The Crossway     0.0
# 9b Bewdley St       1.0
# 9b Latham St        1.0
# 9b Marquis Rd       1.0
# 9b Stewart St       0.0
# Name: Bathroom, Length: 34009, dtype: float64

# %%
df.isnull().mean()
# Out:
# Suburb           0.000000
# Address          0.000000
# Rooms            0.000000
# Type             0.000000
# Price            0.218321
# Method           0.000000
# SellerG          0.000000
# Date             0.000000
# Distance         0.000029
# Postcode         0.000029
# Bedroom2         0.235735
# Bathroom         0.000000
# Car              0.250394
# Landsize         0.338813
# BuildingArea     0.605761
# YearBuilt        0.553863
# CouncilArea      0.000086
# Lattitude        0.228821
# Longtitude       0.228821
# Regionname       0.000086
# Propertycount    0.000086
# dtype: float64

# %%
def impute_nan(df, variable, median):
    df[variable+ "_median"] = df[variable].fillna(median)

# %%
median = df.Price.median()
median
# Out:
# 870000.0

# %%
impute_nan(df, 'Price', median)
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/09/2016       2.5    3067.0  ...  1.0     126.0           NaN        NaN
# 1  3/12/2016       2.5    3067.0  ...  1.0     202.0           NaN        NaN
# 2  4/02/2016       2.5    3067.0  ...  0.0     156.0          79.0     1900.0
# 3  4/02/2016       2.5    3067.0  ...  1.0       0.0           NaN        NaN
# 4  4/03/2017       2.5    3067.0  ...  0.0     134.0         150.0     1900.0
#
# ...

# %%
df.isnull().mean()
# Out:
# Suburb           0.000000
# Address          0.000000
# Rooms            0.000000
# Type             0.000000
# Price            0.218321
# Method           0.000000
# SellerG          0.000000
# Date             0.000000
# Distance         0.000029
# Postcode         0.000029
# Bedroom2         0.235735
# Bathroom         0.000000
# Car              0.250394
# Landsize         0.338813
# BuildingArea     0.605761
# YearBuilt        0.553863
# CouncilArea      0.000086
# Lattitude        0.228821
# Longtitude       0.228821
# Regionname       0.000086
# Propertycount    0.000086
# Price_median     0.000000
# dtype: float64

# %%
print(df['Price'].std())
print(df['Landsize'].std())
# Out:
# 641467.1301046001
# 3398.8419464599097

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
df['Price'].plot(kind = 'kde', ax =ax)
df.Price_median.plot(kind = 'kde', ax = ax, color = 'red')
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels,loc = 'best')

# %%
df['Price'].dropna().sample(df['Price'].isnull().sum(), random_state=0)
# Out:
# 22635    1130000.0
# 29520     550000.0
# 32893     791000.0
# 27901     855000.0
# 4319      775000.0
#            ...
# 29343    1607500.0
# 2089     1815000.0
# 8088      712500.0
# 7018     1105000.0
# 27265     710000.0
# Name: Price, Length: 7610, dtype: float64

# %%
def impute_nan(df, variable, median):   ##we can use mean as well but there can be few outliers so to remove thrmem we are using median 
    df[variable+"_median"] = df[variable].fillna(median)
    df[variable+"_random"] = df[variable]
    #it will have random sam[ple tot fill the na
    random_sample = df[variable].dropna().sample(df['Price'].isnull().sum(), random_state=0)  ##picking any 1 value
    #pandas needs to have same index in order to merge the dataset.
    random_sample.index = df[df[variable].isnull()].index
    df.loc[df[variable].isnull(), variable+'_random'] = random_sample ##replace null with random sample

# %%
median = df.Price.median()

# %%
impute_nan(df,"Price", median)

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Landsize  BuildingArea  YearBuilt  \
# 0  3/09/2016       2.5    3067.0  ...     126.0           NaN        NaN
# 1  3/12/2016       2.5    3067.0  ...     202.0           NaN        NaN
# 2  4/02/2016       2.5    3067.0  ...     156.0          79.0     1900.0
# 3  4/02/2016       2.5    3067.0  ...       0.0           NaN        NaN
# 4  4/03/2017       2.5    3067.0  ...     134.0         150.0     1900.0
#
#           CouncilArea  Lattitude  Longtitude             Regionname  \
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(111)    
df['Price'].plot(kind = 'kde', ax =ax)
df.Price_median.plot(kind = 'kde', ax =ax, color = 'red')
df.Price_random.plot(kind = 'kde', ax =ax, color = 'green')
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc = 'best')

# %%
df.Price.hist(bins = 50)
# Out:
# <AxesSubplot:>

# %%
extreme = df.Price.mean()+3*df.Price.std()

# %%
def impute_nan(df, variable, median,extreme):
    df[variable+'_end_distribution']= df[variable].fillna(extreme)
    df[variable].fillna(median, inplace = True)

# %%
impute_nan(df,'Price', df.Price.median(), extreme)

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h   870000.0     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u   870000.0     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  BuildingArea  YearBuilt  \
# 0  3/09/2016       2.5    3067.0  ...           NaN        NaN
# 1  3/12/2016       2.5    3067.0  ...           NaN        NaN
# 2  4/02/2016       2.5    3067.0  ...          79.0     1900.0
# 3  4/02/2016       2.5    3067.0  ...           NaN        NaN
# 4  4/03/2017       2.5    3067.0  ...         150.0     1900.0
#
#           CouncilArea  Lattitude  Longtitude             Regionname  \
# 0  Yarra City Council   -37.8014    144.9958  Northern Metropolitan
# ...

# %%
df['Price'].hist(bins = 50)
# Out:
# <AxesSubplot:>
